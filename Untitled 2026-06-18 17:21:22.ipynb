# %%
# Python cell - basic compute
import sys
print(f"Python version: {sys.version}")
print("Git integration test - Python cell")

# %%
-- SQL cell - Athena compute
SELECT 'Git integration test - SQL cell' AS message, current_timestamp AS ts

# %%
# Spark cell - Glue/EMR compute
# Switch to Spark connection in Compute panel to run this
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
df = spark.createDataFrame([("Git integration test - Spark cell",)], ["message"])
df.show()
